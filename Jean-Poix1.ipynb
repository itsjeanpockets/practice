# %% [markdown]
# # Vanessa Jean-Poix

# %% [markdown]
# ## Phases of Analysis and Visualization
# 1. **Get the data:** Find the data on a website or in one of your company’s databases or spreadsheets. Read the data into a DataFrame or build a DataFrame from the data.
# 2. **Clean the data:** Remove unnecessary rows and columns. Handle invalid or missing values. Change object data types to datetime or numeric data types.
# 3. **Prepare the data:** Add columns that are derived from other columns. Shape the data into the forms that are needed for your analysis. Make preliminary visualizations to better understand the data.
# 4. **Analyze the data:** Get new views of the data by grouping and aggregating the data. Make visualizations that provide insights and show relationships.Model the data as part of predictive analysis.
# 5. **Visualize the data:** Enhance your visualizations so they’re appropriate for your target audience.

# %% [markdown]
# # Exercise 1-1: Get started with JupyterLab

# %% [markdown]
# ## Get the data

# %%
import pandas as pd
poll_url = 'http://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv'
polls = pd.read_csv(poll_url)

# %%
polls.head()
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
#   state  startdate    enddate                  pollster grade  ...  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+  ...
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B  ...
# 2  U.S.  11/2/2016  11/6/2016                     Ipsos    A-  ...
# 3  U.S.  11/4/2016  11/7/2016                    YouGov     B  ...
# 4  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-  ...
#
#    adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %%
polls.sort_values('state', inplace=True)
polls.head(2)
# Out:
# <ipython-input-11-8a1bd7ca1809>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   polls.sort_values('state', inplace=True)
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6148   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state   startdate    enddate      pollster grade  ...  \
# 7434  Alabama   7/29/2016  8/18/2016         Ipsos    A-  ...
# 6148  Alabama  10/26/2016  11/1/2016  SurveyMonkey    C-  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 7434         36.01944      56.00800              NaN               NaN
# 6148         35.62576      52.09648         1.135647               NaN
#
# ...

# %% [markdown]
# ## Use tab completion and tooltips

# %%
polls.sort_values('state',ascending=False)
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 5595   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5465   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6367   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5566   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5518   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# ...     ...        ...       ...                            ...          ...
# 6336   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6213   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6225   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7142   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
# ...

# %% [markdown]
# ## Clean the data

# %% [markdown]
# ### Keep only the rows with "now-cast" in the type column

# %%
polls = polls.query('type=="now-cast"')
polls.head()
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6148   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6096   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7214   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5504   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state   startdate    enddate           pollster grade  ...  \
# 7434  Alabama   7/29/2016  8/18/2016              Ipsos    A-  ...
# 6148  Alabama  10/26/2016  11/1/2016       SurveyMonkey    C-  ...
# 6096  Alabama   9/23/2016  10/6/2016              Ipsos    A-  ...
# 7214  Alabama   8/12/2016   9/1/2016              Ipsos    A-  ...
# 5504  Alabama   7/19/2016  7/19/2016  Strategy Research   NaN  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %% [markdown]
# ### Rename voting columns

# %%
polls.rename(columns={'rawpoll_clinton':'Clinton_pct',
                      'rawpoll_trump':'Trump_pct'},inplace=True)
polls.head()
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6148   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6096   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7214   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5504   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state   startdate    enddate           pollster grade  ...  \
# 7434  Alabama   7/29/2016  8/18/2016              Ipsos    A-  ...
# 6148  Alabama  10/26/2016  11/1/2016       SurveyMonkey    C-  ...
# 6096  Alabama   9/23/2016  10/6/2016              Ipsos    A-  ...
# 7214  Alabama   8/12/2016   9/1/2016              Ipsos    A-  ...
# 5504  Alabama   7/19/2016  7/19/2016  Strategy Research   NaN  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %% [markdown]
# ### Convert date columns to datetime objects

# %%
date_cols = ["startdate","enddate"]
polls[date_cols] = polls[date_cols].apply(pd.to_datetime)
polls.head()
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6148   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6096   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7214   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5504   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state  startdate    enddate           pollster grade  ...  \
# 7434  Alabama 2016-07-29 2016-08-18              Ipsos    A-  ...
# 6148  Alabama 2016-10-26 2016-11-01       SurveyMonkey    C-  ...
# 6096  Alabama 2016-09-23 2016-10-06              Ipsos    A-  ...
# 7214  Alabama 2016-08-12 2016-09-01              Ipsos    A-  ...
# 5504  Alabama 2016-07-19 2016-07-19  Strategy Research   NaN  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %% [markdown]
# ### Try two plots

# %%
polls.plot.line(x='enddate',y=['Clinton_pct','Trump_pct'])
# Out:
# <AxesSubplot:xlabel='enddate'>

# %%
polls.query('state == "U.S."') \
    .plot(x='enddate',y=['Clinton_pct','Trump_pct'])
# Out:
# <AxesSubplot:xlabel='enddate'>

# %%
# %%time
polls.query
# Out:
# Wall time: 0 ns
# <bound method DataFrame.query of       cycle     branch      type                        matchup forecastdate  \
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6148   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6096   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7214   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5504   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# ...     ...        ...       ...                            ...          ...
# 5106   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6641   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 5908   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6453   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# ...

# %%
# %whos
# Out:
# Variable    Type         Data/Info
# ----------------------------------
# date_cols   list         n=2
# pd          module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# poll_url    str          http://projects.fivethirt<...>nt_general_polls_2016.csv
# polls       DataFrame          cycle     branch   <...>n[4208 rows x 27 columns]

# %%
type(polls)
# Out:
# pandas.core.frame.DataFrame
